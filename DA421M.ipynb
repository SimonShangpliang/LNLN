# %%
# !git clone https://github.com/SimonShangpliang/LNLN.git
# !git clone https://github.com/thuiar/MMSA.git
# Out:
# Cloning into 'LNLN'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 75 (delta 37), reused 56 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 24.45 KiB | 8.15 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Cloning into 'MMSA'...
# remote: Enumerating objects: 1400, done.
# remote: Counting objects: 100% (431/431), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 1400 (delta 335), reused 307 (delta 301), pack-reused 969 (from 1)
# Receiving objects: 100% (1400/1400), 9.30 MiB | 16.54 MiB/s, done.
# Resolving deltas: 100% (839/839), done.

# %%
# !pip install torch torchvision torchaudio
# !pip install numpy pyyaml tqdm
# %cd MMSA
# !pip install .
# %cd /content/LNLN
# Out:
# ...
# /content/MMSA
# Processing /content/MMSA
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 142.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 9.7 MB/s eta 0:00:00
# ...
#   Created wheel for MMSA: filename=mmsa-2.2.1-py3-none-any.whl size=138571 sha256=c40fa4d8bdd2330648947c1199dedef6094f4f00f369ebb2249ad32d643d6235
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t9ajwa1n/wheels/1b/e7/13/d11238c9c9cb6758b7270576079a7baa32137608c3d3dbcff1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# bash train.sh

# %%
# !python robust_evaluation.py --config_file configs/eval_mosi.yaml --key_eval MAE
# Out:
# 2025-11-06 20:01:54.701629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762459314.743947   46407 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762459314.752941   46407 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762459314.788731   46407 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python robust_evaluation.py --config_file configs/eval_mosi.yaml --key_eval Mult_acc_5
# Out:
# 2025-11-06 20:16:46.686564: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762460206.876814   51025 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762460206.934132   51025 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762460207.322416   51025 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python robust_evaluation.py --config_file configs/eval_mosi.yaml --key_eval Mult_acc_7
# Out:
# 2025-11-06 20:31:16.343338: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762461076.402583   55520 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762461076.411618   55520 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762461076.528499   55520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
